# %% [markdown]
# <a href="https://colab.research.google.com/github/alphaolomi/colab-basics/blob/master/Arima_Start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot

# %%
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

# %%
series = read_csv('/content/shampoo.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
print(series.head())
series.plot()
pyplot.show()
# Out:
# Month
# 1901-01-01    266.0
# 1901-02-01    145.9
# 1901-03-01    183.1
# 1901-04-01    119.3
# 1901-05-01    180.3
# Name: Sales, dtype: float64
